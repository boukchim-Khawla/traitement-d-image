# %% [markdown]
# <a href="https://colab.research.google.com/github/boukchim-Khawla/traitement-d-image/blob/main/Seuillage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install bing-image-downloader

# %%
# !mkdir imgg

# %%
from bing_image_downloader import downloader
downloader.download("IRM Coeur", limit=20, output_dir='imgg')
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://irmcardiaque.com/images/c/c5/LE.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.revmed.ch/var/site/storage/images/rms-297/images/rms_idpas_d_isbn_pu2011-21s_sa04_art04_img004.jpg/1035589-1-fre-CH/RMS_idPAS_D_ISBN_pu2011-21s_sa04_art04_img004.jpg_i1140.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.info-radiologie.ch/calcul-choledocien-irm/fullsize/calcul-choledocien-irm-5.0001_fs.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://info-radiologie.ch/tomodensitometrie-thorax/fullsize/tomodensitometrie-thorax-05_fs.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://img0.mxstatic.com/maladie-cardiaque/coeur-humain-illustration_13564_w696.jpg
# [!] Issue getting: http://img0.mxstatic.com/maladie-cardiaque/coeur-humain-illustration_13564_w696.jpg
# ...

# %%
import matplotlib.pyplot as plt
from skimage.io import imread , imshow
from skimage import exposure
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
import numpy as np
from skimage.filters import threshold_mean , threshold_otsu
import pandas as pd

# %%
image1_gray = imread('/content/imgg/IRM Coeur/Image_1.jpg', as_gray=True)

# %%
def histGrayScale(img, _xlim=255, _ylim=2400):
  _, axes = plt.subplots(ncols=2, figsize=(12 , 3))
  ax = axes.ravel()
  ax[0].imshow(img, cmap=plt.get_cmap('gray'))
  ax[0].set_title('Image')
  hist= exposure.histogram(img)
  ax[1].plot(hist[0])
  ax[1].set_xlim([0, _xlim])
  ax[1].set_ylim([0, _ylim])

# %%
histGrayScale(image1_gray)

# %%
def thresholdMeanDisplay(image):
 thresh = threshold_mean(image)
 binary = image > thresh
 fig, axes=plt.subplots(ncols=2,figsize=(8, 3))
 ax= axes.ravel()
 ax[0].imshow(image, cmap=plt.cm.gray)
 ax[0].set_title('Original')
 ax[1].imshow(binary, cmap=plt.cm.gray)
 ax[1].set_title('Mean thresolded')
thresholdMeanDisplay(image1_gray)
